# %% [markdown]
# <a href="https://colab.research.google.com/github/meghadandapat/DSBDAL/blob/main/PreProcessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("dataset_Facebook.csv", ";")

# %%
data.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  Lifetime Post Consumers  \
# ...

# %%
data.isnull().sum()
# Out:
# Page total likes                                                       0
# Type                                                                   0
# Category                                                               0
# Post Month                                                             0
# Post Weekday                                                           0
# Post Hour                                                              0
# Paid                                                                   1
# Lifetime Post Total Reach                                              0
# Lifetime Post Total Impressions                                        0
# Lifetime Engaged Users                                                 0
# Lifetime Post Consumers                                                0
# Lifetime Post Consumptions                                             0
# Lifetime Post Impressions by people who have liked your Page           0
# ...

# %%
data.describe()
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  499.000000                  500.00000                     5.000000e+02
# mean     0.278557                13903.36000                     2.958595e+04
# ...

# %%
import seaborn as sns
typePlot = sns.countplot(data=data,x='Type')

# %%
photo = data[data['Type']=="Photo"]

# %%
photo
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0              139441  Photo         2          12             4          3
# 2              139441  Photo         3          12             3          3
# 3              139441  Photo         2          12             2         10
# 4              139441  Photo         2          12             2          3
# 6              139441  Photo         3          12             1          3
# ..                ...    ...       ...         ...           ...        ...
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
# 499             81370  Photo         2           1             4          4
#
# ...

# %%
status = data[data['Type']=="Status"]
status
# Out:
#      Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 1              139441  Status         2          12             3         10
# 5              139441  Status         2          12             1          9
# 8              139441  Status         2          12             7          3
# 10             139441  Status         2          12             5         10
# 15             138414  Status         2          12             3         10
# 18             138414  Status         3          12             2          3
# 24             138414  Status         2          12             6         10
# 25             138458  Status         2          12             6          3
# 26             138458  Status         2          12             5         11
# 38             138895  Status         2          12             7          9
# 40             138895  Status         2          12             6         11
# ...

# %%
df_modified = [photo,status]

# %%
merged_data = pd.merge(photo,status)
merged_data
# Out:
# Empty DataFrame
# Columns: [Page total likes, Type, Category, Post Month, Post Weekday, Post Hour, Paid, Lifetime Post Total Reach, Lifetime Post Total Impressions, Lifetime Engaged Users, Lifetime Post Consumers, Lifetime Post Consumptions, Lifetime Post Impressions by people who have liked your Page, Lifetime Post reach by people who like your Page, Lifetime People who have liked your Page and engaged with your post, comment, like, share, Total Interactions]
# Index: []

# %%
subset = data.loc[0:10,["comment","like","share"]]
subset
# Out:
#     comment    like  share
# 0         4    79.0   17.0
# 1         5   130.0   29.0
# 2         0    66.0   14.0
# 3        58  1572.0  147.0
# 4        19   325.0   49.0
# 5         1   152.0   33.0
# 6         3   249.0   27.0
# 7         0   325.0   14.0
# 8         0   161.0   31.0
# 9         3   113.0   26.0
# 10        0   233.0   19.0

# %%
subset_long = subset.melt(var_name="interaction",value_name="count")
subset_long
# Out:
#    interaction   count
# 0      comment     4.0
# 1      comment     5.0
# 2      comment     0.0
# 3      comment    58.0
# 4      comment    19.0
# 5      comment     1.0
# 6      comment     3.0
# 7      comment     0.0
# 8      comment     0.0
# 9      comment     3.0
# 10     comment     0.0
# 11        like    79.0
# 12        like   130.0
# 13        like    66.0
# 14        like  1572.0
# 15        like   325.0
# 16        like   152.0
# 17        like   249.0
# 18        like   325.0
# 19        like   161.0
# 20        like   113.0
# 21        like   233.0
# 22       share    17.0
# 23       share    29.0
# 24       share    14.0
# 25       share   147.0
# 26       share    49.0
# 27       share    33.0
# 28       share    27.0
# 29       share    14.0
# 30       share    31.0
# 31       share    26.0
# 32       share    19.0

# %%
subset_wide = subset_long.pivot(columns="interaction",values="count")
subset_wide
# Out:
# interaction  comment    like  share
# 0                4.0     NaN    NaN
# 1                5.0     NaN    NaN
# 2                0.0     NaN    NaN
# 3               58.0     NaN    NaN
# 4               19.0     NaN    NaN
# 5                1.0     NaN    NaN
# 6                3.0     NaN    NaN
# 7                0.0     NaN    NaN
# 8                0.0     NaN    NaN
# 9                3.0     NaN    NaN
# 10               0.0     NaN    NaN
# 11               NaN    79.0    NaN
# 12               NaN   130.0    NaN
# 13               NaN    66.0    NaN
# 14               NaN  1572.0    NaN
# 15               NaN   325.0    NaN
# 16               NaN   152.0    NaN
# 17               NaN   249.0    NaN
# 18               NaN   325.0    NaN
# 19               NaN   161.0    NaN
# 20               NaN   113.0    NaN
# 21               NaN   233.0    NaN
# 22               NaN     NaN   17.0
# 23               NaN     NaN   29.0
# 24               NaN     NaN   14.0
# ...
